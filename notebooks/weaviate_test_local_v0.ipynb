# %%
# !curl -fsSL https://tailscale.com/install.sh | sh

# %%
# !sudo tailscaled \
  --state=/tmp/tailscale.state \
  --socket=/tmp/tailscale.sock \
  --tun=userspace-networking \
  --socks5-server=localhost:1055 \
  >/tmp/ts.log 2>&1 &

# %%
# !sudo pkill tailscaled || true
# !sudo tailscaled --state=/tmp/tailscale.state --socket=/tmp/tailscale.sock --tun=userspace-networking --socks5-server=localhost:1055 >/tmp/ts.log 2>&1 &

# %%
# !sudo tailscale --socket=/tmp/tailscale.sock up

# %%
# !sudo tailscale --socket=/tmp/tailscale.sock status

# %%
# !sudo apt-get -y install curl >/dev/null
# !curl -s --proxy socks5h://localhost:<SOCKS_PORT> http://<WEAVIATE_HOST>:<PORT>/v1/meta | head
