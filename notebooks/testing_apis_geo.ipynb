# %%
import geopandas as gpd

gdf = gpd.read_file(
    "https://echanges.brest-metropole.fr/VIPDU72/GPB/DEP_COL_BusTram_Arrets.zip"
)

print(gdf.head())
# Out:
#    OBJECTID         STATION     ARRET DIRECTION  SENS              X  \
# 0         0        Fourneuf   FOURN_1      None  None  149724.638150
# 1         0        Fourneuf   FOURN_2      None  None  149704.623555
# 2         0  Foyer du marin  FOYERM_1      None  None  146878.765575
# 3         0        Franklin  FRANKL_1      None  None  145957.117340
# 4         0        Franklin  FRANKL_2      None  None  145974.092904
#
#               Y                     LIGNE RESEAU     NSTAT ACCESSIBLE  DEPCO  \
# 0  6.841655e+06                  69,68,67   None   FOURN_1          0  29061
# 1  6.841678e+06                  69,68,67   None   FOURN_2          0  29061
# 2  6.836190e+06  19,16,26,01,02B,78,45,90   None  FOYERM_1          0  29019
# 3  6.838301e+06                        46   None  FRANKL_1          1  29019
# 4  6.838296e+06                        46   None  FRANKL_2          1  29019
#
#                          geometry
# 0  POINT (149724.638 6841654.638)
# ...
